# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_parquet('/home/awardana/.cache/kagglehub/datasets/dhoogla/nfunswnb15v2/versions/2/NF-UNSW-NB15-V2.parquet', engine='pyarrow')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986745 entries, 0 to 1986744
# Data columns (total 43 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   L4_SRC_PORT                  int32
#  1   L4_DST_PORT                  int32
#  2   PROTOCOL                     int16
#  3   L7_PROTO                     float32
#  4   IN_BYTES                     int32
#  5   IN_PKTS                      int16
#  6   OUT_BYTES                    int32
#  7   OUT_PKTS                     int16
#  8   TCP_FLAGS                    int8
#  9   CLIENT_TCP_FLAGS             int8
#  10  SERVER_TCP_FLAGS             int8
#  11  FLOW_DURATION_MILLISECONDS   int32
#  12  DURATION_IN                  int16
#  13  DURATION_OUT                 int16
#  14  MIN_TTL                      int16
#  15  MAX_TTL                      int16
#  16  LONGEST_FLOW_PKT             int16
#  17  SHORTEST_FLOW_PKT            int16
#  18  MIN_IP_PKT_LEN               int16
# ...

# %%
df['Label'].value_counts()
# Out:
# Label
# 0    1911666
# 1      75079
# Name: count, dtype: int64

# %%
df = df.drop(df.columns[[0, 1, 42]], axis=1)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986745 entries, 0 to 1986744
# Data columns (total 40 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   PROTOCOL                     int16
#  1   L7_PROTO                     float32
#  2   IN_BYTES                     int32
#  3   IN_PKTS                      int16
#  4   OUT_BYTES                    int32
#  5   OUT_PKTS                     int16
#  6   TCP_FLAGS                    int8
#  7   CLIENT_TCP_FLAGS             int8
#  8   SERVER_TCP_FLAGS             int8
#  9   FLOW_DURATION_MILLISECONDS   int32
#  10  DURATION_IN                  int16
#  11  DURATION_OUT                 int16
#  12  MIN_TTL                      int16
#  13  MAX_TTL                      int16
#  14  LONGEST_FLOW_PKT             int16
#  15  SHORTEST_FLOW_PKT            int16
#  16  MIN_IP_PKT_LEN               int16
#  17  MAX_IP_PKT_LEN               int16
# ...

# %%
df['Label'].value_counts()
# Out:
# Label
# 0    1911666
# 1      75079
# Name: count, dtype: int64

# %%
train, test = train_test_split(df, test_size=0.3, random_state=100)

# %%
train['Label'].value_counts()
# Out:
# Label
# 0    1338025
# 1      52696
# Name: count, dtype: int64

# %%
test['Label'].value_counts()
# Out:
# Label
# 0    573641
# 1     22383
# Name: count, dtype: int64

# %%
train, sample = train_test_split(train, test_size=0.1, random_state=100)

# %%
train['Label'].value_counts()
# Out:
# Label
# 0    1204262
# 1      47386
# Name: count, dtype: int64

# %%
sample['Label'].value_counts()
# Out:
# Label
# 0    133763
# 1      5310
# Name: count, dtype: int64

# %%
train.to_parquet(f"./NF-UNSW-NB15-V2_train.parquet")

# %%
sample.to_parquet(f"./NF-UNSW-NB15-V2_sample.parquet")

# %%
test, valid = train_test_split(test, test_size=0.1, random_state=100)

# %%
test['Label'].value_counts()
# Out:
# Label
# 0    516227
# 1     20194
# Name: count, dtype: int64

# %%
valid['Label'].value_counts()
# Out:
# Label
# 0    57414
# 1     2189
# Name: count, dtype: int64

# %%
test.to_parquet(f"./NF-UNSW-NB15-V2_test.parquet")

# %%
valid.to_parquet(f"./NF-UNSW-NB15-V2_valid.parquet")
