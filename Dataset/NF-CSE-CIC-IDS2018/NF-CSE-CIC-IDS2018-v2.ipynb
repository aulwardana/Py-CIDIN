# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_parquet('/home/awardana/.cache/kagglehub/datasets/dhoogla/nfcsecicids2018v2/versions/2/NF-CSE-CIC-IDS2018-V2.parquet', engine='pyarrow')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17129715 entries, 0 to 17129714
# Data columns (total 43 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   L4_SRC_PORT                  int32
#  1   L4_DST_PORT                  int32
#  2   PROTOCOL                     int8
#  3   L7_PROTO                     float32
#  4   IN_BYTES                     int32
#  5   IN_PKTS                      int32
#  6   OUT_BYTES                    int32
#  7   OUT_PKTS                     int32
#  8   TCP_FLAGS                    int16
#  9   CLIENT_TCP_FLAGS             int16
#  10  SERVER_TCP_FLAGS             int16
#  11  FLOW_DURATION_MILLISECONDS   int32
#  12  DURATION_IN                  int32
#  13  DURATION_OUT                 int32
#  14  MIN_TTL                      int16
#  15  MAX_TTL                      int16
#  16  LONGEST_FLOW_PKT             int32
#  17  SHORTEST_FLOW_PKT            int16
# ...

# %%
df['Label'].value_counts()
# Out:
# Label
# 0    15101685
# 1     2028030
# Name: count, dtype: int64

# %%
df = df.drop(df.columns[[0, 1, 42]], axis=1)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17129715 entries, 0 to 17129714
# Data columns (total 40 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   PROTOCOL                     int8
#  1   L7_PROTO                     float32
#  2   IN_BYTES                     int32
#  3   IN_PKTS                      int32
#  4   OUT_BYTES                    int32
#  5   OUT_PKTS                     int32
#  6   TCP_FLAGS                    int16
#  7   CLIENT_TCP_FLAGS             int16
#  8   SERVER_TCP_FLAGS             int16
#  9   FLOW_DURATION_MILLISECONDS   int32
#  10  DURATION_IN                  int32
#  11  DURATION_OUT                 int32
#  12  MIN_TTL                      int16
#  13  MAX_TTL                      int16
#  14  LONGEST_FLOW_PKT             int32
#  15  SHORTEST_FLOW_PKT            int16
#  16  MIN_IP_PKT_LEN               int16
#  17  MAX_IP_PKT_LEN               int32
# ...

# %%
df['Label'].value_counts()
# Out:
# Label
# 0    15101685
# 1     2028030
# Name: count, dtype: int64

# %%
train, test = train_test_split(df, test_size=0.3, random_state=100)

# %%
train['Label'].value_counts()
# Out:
# Label
# 0    10570954
# 1     1419846
# Name: count, dtype: int64

# %%
test['Label'].value_counts()
# Out:
# Label
# 0    4530731
# 1     608184
# Name: count, dtype: int64

# %%
train, sample = train_test_split(train, test_size=0.1, random_state=100)

# %%
train['Label'].value_counts()
# Out:
# Label
# 0    9513872
# 1    1277848
# Name: count, dtype: int64

# %%
sample['Label'].value_counts()
# Out:
# Label
# 0    1057082
# 1     141998
# Name: count, dtype: int64

# %%
train.to_parquet(f"./NF-CSE-CIC-IDS2018-V2_train.parquet")

# %%
sample.to_parquet(f"./NF-CSE-CIC-IDS2018-V2_sample.parquet")

# %%
test, valid = train_test_split(test, test_size=0.1, random_state=100)

# %%
test['Label'].value_counts()
# Out:
# Label
# 0    4077413
# 1     547610
# Name: count, dtype: int64

# %%
valid['Label'].value_counts()
# Out:
# Label
# 0    453318
# 1     60574
# Name: count, dtype: int64

# %%
test.to_parquet(f"./NF-CSE-CIC-IDS2018-V2_test.parquet")

# %%
valid.to_parquet(f"./NF-CSE-CIC-IDS2018-V2_valid.parquet")
